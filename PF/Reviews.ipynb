# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
dataReview = pd.read_csv('data/googleplaystore_user_reviews.csv')
dataReview.info()
dataReview = dataReview.dropna(subset=['Sentiment'])
dataReview = dataReview.reset_index(drop=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
# App                       64295 non-null object
# Translated_Review         37427 non-null object
# Sentiment                 37432 non-null object
# Sentiment_Polarity        37432 non-null float64
# Sentiment_Subjectivity    37432 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
def sentimentTrans(sent):
    if sent == "Positive":
        return 1
    elif sent == "Neutral":
        return 0
    elif sent == "Negative":
        return -1
    return sent
data["Sentiment"] = data["Sentiment"].map(sentimentTrans).astype(int)

# %%
appRat = dataReview.loc[data['App'] == "Candy Crush Saga"]
sumSent=sum(appRat["Sentiment"])

sumPol=sum(appRat["Sentiment_Polarity"])
sumSub=sum(appRat["Sentiment_Subjectivity"])
print(sumSent,sumPol,sumSub)
print(len(appRat["App"]))
# Out:
# -24 7.456287698412691 109.51026984126976
# 240

# %%
appInfo = dict()
for key in dataReview["App"]:
    appInfo[key] = appInfo.get(key, {'count':0})
    appInfo[key]['count']+=1
    
for key in appInfo:
    appRat = dataReview.loc[data['App'] == key]
    appInfo[key]["sumSent"]=sum(appRat["Sentiment"])
    appInfo[key]["sumPol"]=sum(appRat["Sentiment_Polarity"])
    appInfo[key]["sumSub"]=sum(appRat["Sentiment_Subjectivity"])
# Out:
# {'10 Best Foods for You': {'count': 194, 'sumSent': 152, 'sumPol': 91.32216720779222, 'sumSub': 96.11821456321451}, '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室': {'count': 40, 'sumSent': 30, 'sumPol': 15.69618253968254, 'sumSub': 21.820650793650792}, '11st': {'count': 40, 'sumSent': 16, 'sumPol': 7.251768578643578, 'sumSub': 17.758277417027422}, '1800 Contacts - Lens Store': {'count': 80, 'sumSent': 58, 'sumPol': 25.451581890331894, 'sumSub': 47.287878787878796}, '1LINE – One Line with One Touch': {'count': 38, 'sumSent': 19, 'sumPol': 7.459031385281382, 'sumSub': 21.177981601731606}, '2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif': {'count': 32, 'sumSent': 24, 'sumPol': 14.38611111111111, 'sumSub': 16.658333333333335}, '21-Day Meditation Experience': {'count': 80, 'sumSent': 58, 'sumPol': 20.64109427609428, 'sumSub': 44.083839216339214}, '2Date Dating App, Love and matching': {'count': 38, 'sumSent': 19, 'sumPol': 10.65015247007894, 'sumSub': 21.218848145318734}, '2GIS: directory & navigat
# ...
